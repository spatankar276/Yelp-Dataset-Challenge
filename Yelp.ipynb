# %%
# %pwd
# Out:
# '/Users/SwarajPatankar/Desktop/Yelp'

# %%
# %ls-a
# Out:
# ./
# ../
# .DS_Store
# .ipynb_checkpoints/
# Dataset_Challenge_Dataset_Agreement.pdf
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Weather Data.ipynb
# Yelp.ipynb
# Yelp_Dataset_Challenge_Round_11.pdf
# Yelp_test.ipynb
# business.json
# business_test.json
# checkin.json
# photos.json
# review.json
# tip.json
# user.json
# yelp_dataset.tar

# %%
import ijson
import json
import pandas as pd
import numpy as np
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
# Out:
# /anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
def get_alcohol(json_file):
    f = open(json_file)
    objs = ijson.items(f, '')
    business_id = []
    attributes = []
    for line in f:
        data = json.loads(line)
        business_id.append(data['business_id'])
        attributes.append(data['attributes'])

    alcohol = [None] * len(business_id)
    alc = pd.DataFrame({'business_id' : business_id, 'attributes' : attributes, 'alcohol' : alcohol})
    alc.set_index('business_id', inplace = True)
    pos = -1
    for a in alc['attributes']:
        pos += 1
        for k,v in a.items():
            # get restaurant data only
            if k == 'AcceptsInsurance':
                alc.at[alc.index[pos], 'alcohol'] = 'DROP'
            if k == 'Alcohol':
                alc.at[alc.index[pos], 'alcohol'] = v
    
    alc.drop('attributes', axis = 1, inplace = True)


    return alc

def get_reviews(json_file):
    f = open(json_file)
    objs = ijson.items(f, '')
    business_id = []
    review_id = []
    text = []
    date = []

    for line in f:
        data = json.loads(line)
        business_id.append(data['business_id'])
        review_id.append(data['review_id'])
        text.append(data['text'])
        date.append(data['date'])
    
    reviews = pd.DataFrame({'business_id' : business_id, 'review_id' : review_id,
                               'review_text' : text, 'date' : date})
    return reviews


def get_business(json_file):
    f = open(json_file)
    objs = ijson.items(f, '')
    business_id = []
    address = []
    city = []
    state = []
    postal_code = []
    latitude = []
    longitude = []
    for line in f:
        data = json.loads(line)
        business_id.append(data['business_id'])
        address.append(data['address'])
        city.append(data['city'])
        state.append(data['state'])
        postal_code.append(data['postal_code'])
        latitude.append(data['latitude'])
        longitude.append(data['longitude'])
        
    reviews = pd.DataFrame({'business_id' : business_id, 'address' : address, 
                                   'city' : city, 'state' : state, 'postal_code' : postal_code,
                                   'latitude' : latitude, 'longitude' : longitude})
    return reviews

# %%
alcohol = get_alcohol('business.json')

# %%
reviews = get_reviews('review.json')

# %%
business = get_business('business.json')

# %%
print(reviews['date'].min())
print(reviews['date'].max())
# Out:
# 2004-07-22
# 2017-12-11

# %%
reviews.head()
# Out:
#               business_id        date               review_id  \
# 0  0W4lkclzZThpx3V65bVgig  2016-05-28  v0i_UHJMo_hPBq9bxWvW4w
# 1  AEx2SYEUJmTxVVB18LlCwA  2016-05-28  vkVSCC7xljjrAI4UGfnKEQ
# 2  VR6GpWIda3SfvPC-lg9H3w  2016-05-28  n6QzIUObkYshz4dz2QRJTw
# 3  CKC0-MOWMqoeWf6s-szl8g  2016-05-28  MV3CcKScW05u5LVfF6ok0g
# 4  ACFtxLv8pGrrxMm6EgjreA  2016-05-28  IXvOzsEMYtiJI0CARmj77Q
#
#                                          review_text
# 0  Love the staff, love the meat, love the place....
# 1  Super simple place but amazing nonetheless. It...
# 2  Small unassuming place that changes their menu...
# 3  Lester's is located in a beautiful neighborhoo...
# 4  Love coming here. Yes the place always needs t...

# %%
business.head()
# Out:
#                           address             business_id            city  \
# 0        4855 E Warner Rd, Ste B9  FYWN1wneV18bWNgQjJ2GNg       Ahwatukee
# 1              3101 Washington Rd  He-G7vWjzVUysIKrfNbPUQ        McMurray
# 2          6025 N 27th Ave, Ste 1  KQPW8lFf1y5BT2MxiSZ3QA         Phoenix
# 3  5000 Arizona Mills Cr, Ste 435  8DShNS-LuFqpEWIp0HxijA           Tempe
# 4                    581 Howe Ave  PfOCPjBrlQAnz__NXj9h_w  Cuyahoga Falls
#
#     latitude   longitude postal_code state
# 0  33.330690 -111.978599       85044    AZ
# 1  40.291685  -80.104900       15317    PA
# 2  33.524903 -112.115310       85017    AZ
# 3  33.383147 -111.964725       85282    AZ
# 4  41.119535  -81.475690       44221    OH

# %%
final = reviews.merge(business, how = 'left')

# %%
# how many values are null after the merge?

null_data = final[final.isnull().any(axis=1)]
len(null_data)
# Out:
# 25

# %%
sid = SentimentIntensityAnalyzer()
com = []
pos = []
neg = []
rev = []

# %%
for review in final['review_text']:
    rev.append(review)
    scores =list(sid.polarity_scores(review).values())
    com.append(scores[3])
    pos.append(scores[2])
    neg.append(scores[0])

# %%
df = pd.DataFrame({'review_text' : rev, 'Negative' : neg, 'Positive' : pos, 'Compound' : com})

# %%
final = final.merge(df, how = 'left')

# %%
final.head()
# Out:
#               business_id        date               review_id  \
# 0  0W4lkclzZThpx3V65bVgig  2016-05-28  v0i_UHJMo_hPBq9bxWvW4w
# 1  AEx2SYEUJmTxVVB18LlCwA  2016-05-28  vkVSCC7xljjrAI4UGfnKEQ
# 2  VR6GpWIda3SfvPC-lg9H3w  2016-05-28  n6QzIUObkYshz4dz2QRJTw
# 3  CKC0-MOWMqoeWf6s-szl8g  2016-05-28  MV3CcKScW05u5LVfF6ok0g
# 4  ACFtxLv8pGrrxMm6EgjreA  2016-05-28  IXvOzsEMYtiJI0CARmj77Q
#
#                                          review_text  \
# 0  Love the staff, love the meat, love the place....
# 1  Super simple place but amazing nonetheless. It...
# 2  Small unassuming place that changes their menu...
# 3  Lester's is located in a beautiful neighborhoo...
# 4  Love coming here. Yes the place always needs t...
#
#                         address       city   latitude  longitude postal_code  \
# 0  3895 Boulevard Saint-Laurent   Montréal  45.516373 -73.577537     H2W 1X9
# 1     34 Avenue Fairmount Ouest   Montréal  45.523333 -73.594859     H2T 2M1
# 2         4662 Rue Notre-Dame O   Montréal  45.472902 -73.588321     H4C 1S7
# 3           1057 Avenue Bernard  Outremont  45.522144 -73.607076     H2V 1V1
# 4    698 Rue Sainte-Catherine O   Montréal  45.502510 -73.570119     H3B 1B9
#
#   state  Compound  Negative  Positive
# 0    QC    0.9460     0.032     0.281
# 1    QC    0.9551     0.000     0.355
# 2    QC    0.8167     0.000     0.093
# 3    QC    0.6249     0.000     0.075
# 4    QC    0.8560     0.036     0.123

# %%
final = final.sort_values(['business_id', 'date'])

# %%
print(len(final))
# Out:
# 5269907

# %%
print(final.dtypes)
# Out:
# business_id     object
# date            object
# review_id       object
# review_text     object
# address         object
# city            object
# latitude       float64
# longitude      float64
# postal_code     object
# state           object
# Compound       float64
# Negative       float64
# Positive       float64
# dtype: object

# %%
final['sent_spread'] = final['Positive'] - final['Negative']

# %%
final.head()
# Out:
#                     business_id        date               review_id  \
# 3414767  --6MefnULPED_I942VcFNA  2008-08-07  iT5SDn-i-L2NLMcdyERj0A
# 4015047  --6MefnULPED_I942VcFNA  2010-11-25  aKl1rH7HTkD0stonJP4YHg
# 4797875  --6MefnULPED_I942VcFNA  2010-12-06  hPsTqtjMSde_-v6ZZJiTVw
# 4145814  --6MefnULPED_I942VcFNA  2010-12-22  R8Q9mgL2cWgD5yn9_IA--g
# 836323   --6MefnULPED_I942VcFNA  2011-01-08  s_DQ0OqFZ3a_8MgeU6Sh2w
#
#                                                review_text  \
# 3414767  Chinese name of this place, Canto pronounciati...
# 4015047  If you want a quick fix for a scrumptious char...
# 4797875  In the ultra competitive Chinese restaurant in...
# 4145814  John's Chinese BBQ Restaurant is one of those ...
# 836323   i like humble-pie.\nbut the owner walks around...
#
#                                             address           city   latitude  \
# 3414767  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4015047  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4797875  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4145814  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 836323   328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
#
#          longitude postal_code state  Compound  Negative  Positive  \
# 3414767 -79.399604     L4B 3P7    ON    0.9926     0.050     0.107
# 4015047 -79.399604     L4B 3P7    ON    0.9660     0.015     0.181
# 4797875 -79.399604     L4B 3P7    ON    0.9776     0.046     0.116
# 4145814 -79.399604     L4B 3P7    ON    0.9407     0.072     0.105
# 836323  -79.399604     L4B 3P7    ON    0.9932     0.025     0.220
#
#          sent_spread
# 3414767        0.057
# 4015047        0.166
# 4797875        0.070
# 4145814        0.033
# 836323         0.195

# %%
final.to_csv('final.csv')

# %%
final.head(3)
# Out:
#                     business_id        date               review_id  \
# 3414767  --6MefnULPED_I942VcFNA  2008-08-07  iT5SDn-i-L2NLMcdyERj0A
# 4015047  --6MefnULPED_I942VcFNA  2010-11-25  aKl1rH7HTkD0stonJP4YHg
# 4797875  --6MefnULPED_I942VcFNA  2010-12-06  hPsTqtjMSde_-v6ZZJiTVw
#
#                                                review_text  \
# 3414767  Chinese name of this place, Canto pronounciati...
# 4015047  If you want a quick fix for a scrumptious char...
# 4797875  In the ultra competitive Chinese restaurant in...
#
#                                             address           city   latitude  \
# 3414767  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4015047  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4797875  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
#
#          longitude postal_code state  Compound  Negative  Positive  \
# 3414767 -79.399604     L4B 3P7    ON    0.9926     0.050     0.107
# 4015047 -79.399604     L4B 3P7    ON    0.9660     0.015     0.181
# 4797875 -79.399604     L4B 3P7    ON    0.9776     0.046     0.116
#
#          sent_spread
# 3414767        0.057
# 4015047        0.166
# 4797875        0.070

# %%
alcohol = alcohol.reset_index()
alcohol.head(3)
# Out:
#               business_id alcohol
# 0  He-G7vWjzVUysIKrfNbPUQ    None
# 1  KQPW8lFf1y5BT2MxiSZ3QA    None
# 2  8DShNS-LuFqpEWIp0HxijA    None

# %%
final = final.merge(alcohol)
final.head()
# Out:
#               business_id        date               review_id  \
# 0  --6MefnULPED_I942VcFNA  2008-08-07  iT5SDn-i-L2NLMcdyERj0A
# 1  --6MefnULPED_I942VcFNA  2010-11-25  aKl1rH7HTkD0stonJP4YHg
# 2  --6MefnULPED_I942VcFNA  2010-12-06  hPsTqtjMSde_-v6ZZJiTVw
# 3  --6MefnULPED_I942VcFNA  2010-12-22  R8Q9mgL2cWgD5yn9_IA--g
# 4  --6MefnULPED_I942VcFNA  2011-01-08  s_DQ0OqFZ3a_8MgeU6Sh2w
#
#                                          review_text  \
# 0  Chinese name of this place, Canto pronounciati...
# 1  If you want a quick fix for a scrumptious char...
# 2  In the ultra competitive Chinese restaurant in...
# 3  John's Chinese BBQ Restaurant is one of those ...
# 4  i like humble-pie.\nbut the owner walks around...
#
#                                       address           city   latitude  \
# 0  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 1  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 2  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 3  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
# 4  328 Highway 7 E, Chalmers Gate 11, Unit 10  Richmond Hill  43.840905
#
#    longitude postal_code state  Compound  Negative  Positive  sent_spread  \
# 0 -79.399604     L4B 3P7    ON    0.9926     0.050     0.107        0.057
# 1 -79.399604     L4B 3P7    ON    0.9660     0.015     0.181        0.166
# 2 -79.399604     L4B 3P7    ON    0.9776     0.046     0.116        0.070
# 3 -79.399604     L4B 3P7    ON    0.9407     0.072     0.105        0.033
# 4 -79.399604     L4B 3P7    ON    0.9932     0.025     0.220        0.195
#
#          alcohol
# 0  beer_and_wine
# 1  beer_and_wine
# 2  beer_and_wine
# 3  beer_and_wine
# 4  beer_and_wine

# %%
# gets only restaurants
print(len(final))
final = final[final['alcohol'] != 'DROP']
print(len(final))
# Out:
# 5110391
# 5110391

# %%
# let's bring in weather data too

# %%
import requests, re
def get_weather():
    
    
    
    url = 'https://www.wunderground.com/history/airport/KHWD/2013/4/1/DailyHistory.html?req_city=Fremont&req_state=CA&req_statename=California&reqdb.zip=94555&reqdb.magic=1&reqdb.wmo=99999'
    
    df = pd.read_html(url, header = 0, index_col = 0)
